# %% [markdown]
# <a href="https://colab.research.google.com/github/TienLungSun/Python-/blob/main/IE118%20week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(22+35)*5/20
# Out:
# 14.25

# %%
b = (22+35)*5/20

# %%
print(b)
# Out:
# 14.25

# %%
b+87
# Out:
# 101.25

# %%
ccc = b+87

# %%
print(ccc)
# Out:
# 101.25

# %%
#p.1-12 練習2  123456789 ==> (n)*8+n
12*8+2
# Out:
# 98

# %%
12345678*8+8
# Out:
# 98765432

# %%
1234*8+4
# Out:
# 9876

# %%
#p.1-17 畫圖
import matplotlib.pyplot as plt
plt.plot([1.23, -1.5, 1, -2.45, 3])
plt.show()

# %%
plt.plot([2, -5, 3, 8, -2])
plt.plot([1, 2, 3, 4])
plt.show()

# %%
plt.plot([2, -5, 3, 8, -2])
plt.plot([1, 2, 3, 4])
plt.plot([38.2, 54.6, 128.5, 32.74, 68.521])
plt.show()

# %%
#p.1-20 從 Normal distribution 隨機抽樣
import numpy as np
np.random.randn(5)
# Out:
# array([-0.2529126 , -0.01111145,  0.64361449,  0.12994397,  1.26771357])

# %%
plt.plot(np.random.randn(100))
plt.show()

# %%
plt.figure(figsize=(18, 6))
plt.plot(np.random.randn(5000))
plt.show()

# %%
x = [1,  3.5, 8.34,  4.23, 5.89]
y = [3.2, 4.8, 5.123, 0.23, -6.5]
plt.scatter(x, y)
plt.show()

# %%
x = np.random.randn(50)
y = np.random.randn(50)
plt.scatter(x, y)
plt.show()
