# %% [markdown]
# <a href="https://colab.research.google.com/github/TienLungSun/Python-/blob/main/IE118%20week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(22+35)*5/20
# Out:
# 14.25

# %%
a=(22+35)*5/20

# %%
a
# Out:
# 14.25

# %%
a+87
# Out:
# 101.25

# %%
b = a+87

# %%
b
# Out:
# 101.25

# %%
123456*8+6
# Out:
# 987654

# %%
12345*8+5
# Out:
# 98765

# %%
1234*8+4
# Out:
# 9876

# %%
import matplotlib.pyplot as plt
plt.plot([2, -5, 3, 8, -2])
plt.show()

# %%
plt.plot([2, -5, 3, 8, -2])
plt.plot([1, 2, 3, 4])
plt.show()

# %%
plt.plot([2, -5, 3, 8, -2])
plt.plot([1, 2, 3, 4])
plt.plot([38.2, 54.6, 128.5, 32.74, 68.521])
plt.show()

# %%
import numpy as np
np.random.randn(3)
# Out:
# array([ 0.92439902, -1.82508784,  2.16788375])

# %%
plt.plot(np.random.randn(100))
plt.show()

# %%
plt.figure(figsize=(18, 6))
plt.plot(np.random.randn(5000))
plt.show()

# %%
x = [1,  3.5, 8.34,  4.23, 5.89]
y = [3.2, 4.8, 5.123, 0.23, -6.5]
plt.scatter(x, y)
plt.show()

# %%
x = np.random.randn(50)
y = np.random.randn(50)
plt.scatter(x, y)
plt.show()
